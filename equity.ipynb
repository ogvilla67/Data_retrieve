# %% [markdown]
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://upload.wikimedia.org/wikipedia/commons/d/db/Logo_ITESO_normal.jpg" width="150px" height="90px" />
#
# ## Búsqueda de datos históricos
#
# ### Área de Operación
#
# >##### Pablo Macías
# >##### Oscar Villa

# %%
import pandas as pd
import numpy as np 
import pandas_datareader.data as web

# %%
def get_adj_closes(tickers, start_date=None, end_date=None):
    # Fecha de inicio por defecto '2010-01-01', fecha de fin por defecto 'today'
    closes = web.DataReader(name=tickers, data_source='yahoo', start=start_date, end=end_date)
    closes = closes['Adj Close']
    closes.sort_index(inplace=True)
    return closes

# %%
data = pd.read_excel('Subyacentes.xlsx')
tickers=data['Sof'].tolist()

# %%
hst= get_adj_closes(tickers,'2021-01-04','2021-01-19')
# Out:
# C:\Users\oscar\anaconda3\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ABBN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\oscar\anaconda3\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ABI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\oscar\anaconda3\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'AEROMEX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\oscar\anaconda3\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'AF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\oscar\anaconda3\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'AGN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ...

# %%
hst
# Out:
# Symbols            AA        AAL        AAPL        ABBV         ABT  \
# Date
# 2021-01-04  23.250000  15.130000  129.410004  104.191391  108.672203
# 2021-01-05  23.670000  15.430000  131.009995  105.268791  110.016785
# 2021-01-06  25.209999  15.520000  126.599998  104.359428  109.787712
# 2021-01-07  25.230000  15.380000  130.919998  105.476357  110.853416
# 2021-01-08  24.990000  15.130000  132.050003  106.029884  111.162170
# 2021-01-11  24.559999  15.000000  128.979996  107.759651  110.395256
# 2021-01-12  25.080000  15.380000  128.800003  108.510864  108.403282
# 2021-01-13  24.440001  15.530000  130.889999  111.150002  111.700005
# 2021-01-14  25.090000  16.440001  128.910004  111.629997  110.040001
# 2021-01-15  23.280001  15.760000  127.139999  110.519997  111.300003
# 2021-01-19  22.950001  16.055000  127.899902  111.730003  112.644997
#
# Symbols            AC        ACA        ADBE         ADP        ADS  ...  VIX  \
# ...

# %%
hst.to_excel('historicos.xlsx')
